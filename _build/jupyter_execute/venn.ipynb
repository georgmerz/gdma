# %%
# !pip install matplotlib-venn
# Out:
# Requirement already satisfied: matplotlib-venn in /Users/georg/anaconda3/lib/python3.10/site-packages (0.11.9)
# Requirement already satisfied: matplotlib in /Users/georg/anaconda3/lib/python3.10/site-packages (from matplotlib-venn) (3.7.0)
# Requirement already satisfied: scipy in /Users/georg/anaconda3/lib/python3.10/site-packages (from matplotlib-venn) (1.10.0)
# Requirement already satisfied: numpy in /Users/georg/anaconda3/lib/python3.10/site-packages (from matplotlib-venn) (1.23.5)
# Requirement already satisfied: pillow>=6.2.0 in /Users/georg/anaconda3/lib/python3.10/site-packages (from matplotlib->matplotlib-venn) (9.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/georg/anaconda3/lib/python3.10/site-packages (from matplotlib->matplotlib-venn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/georg/anaconda3/lib/python3.10/site-packages (from matplotlib->matplotlib-venn) (22.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/georg/anaconda3/lib/python3.10/site-packages (from matplotlib->matplotlib-venn) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/georg/anaconda3/lib/python3.10/site-packages (from matplotlib->matplotlib-venn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /Users/georg/anaconda3/lib/python3.10/site-packages (from matplotlib->matplotlib-venn) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/georg/anaconda3/lib/python3.10/site-packages (from matplotlib->matplotlib-venn) (1.0.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/georg/anaconda3/lib/python3.10/site-packages (from matplotlib->matplotlib-venn) (3.0.9)
# Requirement already satisfied: six>=1.5 in /Users/georg/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->matplotlib-venn) (1.16.0)

# %%
#Import libraries
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted
from matplotlib_venn import venn3, venn3_circles
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
venn2(subsets = (30, 30, 10))

# %%
c = venn3_circles(subsets = (20, 10, 12, 10, 9, 4, 3), linestyle='dashed', linewidth=1)
c[0].set_lw(5.0)
c[1].set_lw(8.0)
c[2].set_lw(2.0)
